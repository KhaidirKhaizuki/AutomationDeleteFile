# %%
import os
import glob

# Get a list of all XML files in the current directory and subdirectories
files = glob.glob("**/*.XML", recursive=True)

# Iterate over the list of files
for file in files:
  # Delete each file
  os.remove(file)
  # Print the name of the file that was deleted
  print(f"Deleted file: {file}")
# Out:
# Deleted file: flutter_ecommerce_app-master\android\app\src\main\AndroidManifest.xml
# Deleted file: flutter_ecommerce_app-master\android\app\src\main\res\drawable\launch_background.xml
# Deleted file: flutter_ecommerce_app-master\android\app\src\main\res\values\styles.xml
# Deleted file: flutter_ecommerce_app-master\build\app\intermediates\incremental\mergeDebugAssets\merger.xml
# Deleted file: flutter_ecommerce_app-master\build\app\intermediates\incremental\mergeDebugResources\merger.xml
# Deleted file: flutter_ecommerce_app-master\build\app\intermediates\incremental\mergeDebugResources\merged.dir\values\values.xml
# Deleted file: flutter_ecommerce_app-master\build\app\intermediates\incremental\mergeDebugResources\merged.dir\values-af\values-af.xml
# Deleted file: flutter_ecommerce_app-master\build\app\intermediates\incremental\mergeDebugResources\merged.dir\values-am\values-am.xml
# ...
